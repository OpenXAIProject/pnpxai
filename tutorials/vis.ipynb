# %%
# Out:
# /home/gkim/Projects/pnpxai/.venv/lib/python3.10/site-packages/torch/overrides.py:110: UserWarning: 'has_cuda' is deprecated, please use 'torch.backends.cuda.is_built()'
#   torch.has_cuda,
# /home/gkim/Projects/pnpxai/.venv/lib/python3.10/site-packages/torch/overrides.py:111: UserWarning: 'has_cudnn' is deprecated, please use 'torch.backends.cudnn.is_available()'
#   torch.has_cudnn,
# /home/gkim/Projects/pnpxai/.venv/lib/python3.10/site-packages/torch/overrides.py:117: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   torch.has_mps,
# /home/gkim/Projects/pnpxai/.venv/lib/python3.10/site-packages/torch/overrides.py:118: UserWarning: 'has_mkldnn' is deprecated, please use 'torch.backends.mkldnn.is_available()'
#   torch.has_mkldnn,
# [Run] Explaining GuidedGradCam
# ...

# %%
# Out:
# <div>                            <div id="400aa017-cfee-4a26-a11d-b22395861965" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("400aa017-cfee-4a26-a11d-b22395861965")) {                    Plotly.newPlot(                        "400aa017-cfee-4a26-a11d-b22395861965",                        [{"name":"0","source":"...\u002f22AAEAAElEQVR4Xuz9d5BmSZIfiLl7RDzx6dSqdLXWaqZ7RM8MZmZnd2cFVgMHYgHCQN4dzY7k0UijGc3IMxqM\u002fIP\u002fUpgd7s4OgBkIAiCxOCx2F7OzYrSeaa27S1dlVerMTz0R4e78432ZlZlVmZ1V3b0ze5jf5FS\u002fFy90\u002fMLdwyPe+\u002fDcjRI+GiDi\...\u002fRqFPZFQCQiAFBUEAAAERUZRVBVlYr\u002fI6oTESBUcgMBCAEVlFTVIAIRAhogRERVAgDZFkyIIzlKhMIsUglXAwCGyJABgBDYEFpLhsgaQ0hV7d936D6Mwb3jHBARAFUVEao+rBopogpOEQOL9cF+GJW7icNyO\...\u002f2qwq3\u002f3U+qA2hwQXGFfg3ZwW+7eZjB26nBTNSEg3
# ...

# %%
self.target
# Out:
# ['n03781244', 'monastery']

# %%
px.imshow(self.explanation)
# Out:
# <div>                            <div id="3d012507-5067-43fb-aa67-70eafb2ffdd9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d012507-5067-43fb-aa67-70eafb2ffdd9")) {                    Plotly.newPlot(                        "3d012507-5067-43fb-aa67-70eafb2ffdd9",                        [{"coloraxis":"coloraxis","name":"0","z":[[0.0005361433140933514,0.002475988818332553,0.001786445383913815,0.001414693077094853,0.0017867592396214604,0.0014432212337851524,0.000979697098955512,0.0013254527002573013,0.0008793866727501154,0.0007164134294725955,0.0008714161231182516,0.0009956532157957554,0.0011858352227136493,0.001255723531357944,0.0014589669881388545,0.0013383302139118314,0.000967135711107403,0.0009632601868361235,0.0012586726807057858,0.00142597290
# ...
